# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('tickers.csv')

# Extract the 'Symbol' column into a list
ticker_symbols = df['Symbol'].tolist()

# Print the list to verify
print(ticker_symbols)
# Out:
# ['A', 'AA', 'AACG', 'AACI', 'AACIU', 'AACIW', 'AACT', 'AADI', 'AAGR', 'AAGRW', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AAT', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABEO', 'ABEV', 'ABG', 'ABIO', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABM', 'ABNB', 'ABOS', 'ABR', 'ABR^D', 'ABR^E', 'ABR^F', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVX', 'AC', 'ACA', 'ACAB', 'ACAC', 'ACACU', 'ACACW', 'ACAD', 'ACB', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHR', 'ACHV', 'ACI', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACON', 'ACONW', 'ACP', 'ACP^A', 'ACR', 'ACR^C', 'ACR^D', 'ACRE', 'ACRS', 'ACRV', 'ACST', 'ACT', 'ACTG', 'ACU', 'ACV', 'ACVA', 'ACXP', 'ADAG', 'ADAP', 'ADBE', 'ADC', 'ADC^A', 'ADCT', 'ADD', 'ADEA', 'ADI', 'ADIL', 'ADM', 'ADMA', 'ADN', 'ADNT', 'ADNWW', 'ADP', 'ADPT', 'ADRT', 'ADSE', 'ADSEW', 'ADSK', 'ADT', 'ADTH', 'ADTHW', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'AE', 'AEAE', 'AEAEW', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AENTW', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AERTW', 'AES', 'AESI', 'AEVA', 'AEYE', 'AEZS', 'AFAR', 'AFARW', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFJK', 'AFJKU', 'AFL', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFT', 'AFYA', 'AG', 'AGAE', 'AGBA', 'AGBAW', 'AGCO', 'AGD', 'AGEN', 'AGFY', 'AGI', 'AGIO', 'AGL', 'AGM', 'AGM^C', 'AGM^D', 'AGM^E', 'AGM^F', 'AGM^G', 'AGMH', 'AGNC', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGO', 'AGR', 'AGRI', 'AGRIW', 'AGRO', 'AGS', 'AGX', 'AGYS', 'AHCO', 'AHG', 'AHH', 'AHH^A', 'AHL^C', 'AHL^D', 'AHL^E', 'AHR', 'AHT', 'AHT^D', 'AHT^F', 'A
'APTO', 'APTV', 'APVO', 'APWC', 'APXI', 'APYX', 'AQB', 'AQMS', 'AQN', 'AQNB', 'AQNU', 'AQST', 'AQU', 'AQUNR', 'AR', 'ARAY', 'ARBB', 'ARBE', 'ARBEW', 'ARBK', 'ARBKL', 'ARC', 'ARCB', 'ARCC', 'ARCH', 'ARCO', 'ARCT', 'ARDC', 'ARDX', 'ARE', 'AREB', 'AREBW', 'AREC', 'AREN', 'ARES', 'ARGD', 'ARGO^A', 'ARGX', 'ARHS', 'ARI', 'ARIS', 'ARKO', 'ARKOW', 'ARKR', 'ARL', 'ARLO', 'ARLP', 'ARM', 'ARMK', 'ARMN', 'ARMP', 'AROC', 'AROW', 'ARQ', 'ARQQ', 'ARQQW', 'ARQT', 'ARR', 'ARR^C', 'ARRY',  ...

# %%
import os
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# Directory to save the data
data_dir = "ticker_data"
os.makedirs(data_dir, exist_ok=True)

# Function to fetch and save data for a list of tickers
def fetch_and_save_data(tickers):
    end_date = datetime.now()
    start_date = end_date - timedelta(days=365*10)
    
    try:
        print(f"Fetching data for tickers: {tickers}")
        data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker')
        
        for ticker in tickers:
            ticker_data = data[ticker]
            if not ticker_data.empty:
                file_path = os.path.join(data_dir, f"{ticker}.csv")
                ticker_data.to_csv(file_path)
                print(f"Data for {ticker} saved successfully.")
            else:
                print(f"No data found for {ticker}.")
    except Exception as e:
        print(f"Error fetching data for tickers: {e}")

# Function to split the list into chunks of specified size
def chunk_list(lst, chunk_size):
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# Process tickers in chunks of 500
chunk_size = 500
for ticker_chunk in chunk_list(ticker_symbols, chunk_size):
    fetch_and_save_data(ticker_chunk)

print("Data fetching completed.")
# Out:
# Fetching data for tickers: ['A', 'AA', 'AACG', 'AACI', 'AACIU', 'AACIW', 'AACT', 'AADI', 'AAGR', 'AAGRW', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AAT', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABEO', 'ABEV', 'ABG', 'ABIO', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABM', 'ABNB', 'ABOS', 'ABR', 'ABR^D', 'ABR^E', 'ABR^F', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVX', 'AC', 'ACA', 'ACAB', 'ACAC', 'ACACU', 'ACACW', 'ACAD', 'ACB', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHR', 'ACHV', 'ACI', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACON', 'ACONW', 'ACP', 'ACP^A', 'ACR', 'ACR^C', 'ACR^D', 'ACRE', 'ACRS', 'ACRV', 'ACST', 'ACT', 'ACTG', 'ACU', 'ACV', 'ACV
# ['ALL^I', 'AHT^I', 'AHL^C', 'AGM^D', 'ABR^D', 'ALL^H', 'AHT^D', 'AHH^A', 'AKO/B', 'ANG^B', 'AMH^H', 'AHL^D', 'ALTG^A', 'AHT^H', 'ABR^F', 'AHT^G', 'AKO/A', 'AGM^F', 'AHT^F', 'ANG^A', 'ABR^E', 'AMH^G', 'APO^A', 'ARGO^A', 'ACP^A', 'ADC^A', 'ALL^J', 'ALB^A', 'AHL^E', 'ACR^D', 'AGM^E', 'AL^A', 'ALL^B', 'ACR^C', 'AGM^G', 'AGM^C']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Data for A saved successfully.
# Data for AA saved successfully.
# Data for AACG saved successfully.
# Data for AACI saved successfully.
# Data for AACIU saved successfully.
# Data for AACIW saved successfully.
# Data for AACT saved successfully.
# Data for AADI saved successfully.
# Data for AAGR saved successfully.
# Data for AAGRW saved successfully.
# Data for AAL saved successfully.
# Data for AAMC saved successfully.
# Data for AAME saved successfully.
# Data for AAN saved successfully.
# Data for AAOI saved successfully.
# Data for AAON saved successfully.
# Data for AAP saved successfully.
# Data for AAPL saved successfully.
# Data for AAT saved successfully.
# Data for AB saved successfully.
# Data for ABAT saved successfully.
# Data for ABBV saved successfully.
# Data for ABCB saved successfully.
# Data for ABCL saved successfully.
# Data for ABEO saved successfully.
# Data for ABEV saved successfully.
# Data for ABG saved successfully.
# Data for ABIO saved successfully.
# Data for ABL saved successfully.
# Data for ABLLL saved successfully.
# Data for ABLLW saved successfully.
# Data for ABLV saved successfully.
# Data for ABM saved successfully.
# Data for ABNB saved successfully.
# Data for ABOS saved successfully.
# Data for ABR saved successfully.
# Data for ABR^D saved successfully.
# Data for ABR^E saved successfully.
# Data for ABR^F saved successfully.
# Data for ABSI saved successfully.
# Data for ABT saved successfully.
# Data for ABTS saved successfully.
# Data for ABUS saved successfully.
# Data for ABVC saved successfully.
# Data for ABVX saved successfully.
# Data for AC saved successfully.
# Data for ACA saved successfully.
# Data for ACAB saved successfully.
# Data for ACAC saved successfully.
# Data for ACACU saved successfully.
# Data for ACACW saved successfully.
# Data for ACAD saved successfully.
# Data for ACB saved successfully.
# Data for ACCD saved successfully.
# Data for ACCO saved successfully.
# Data for ACDC saved successfully.
# Data for ACEL saved successfully.
# Data for ACET saved successfully.
# Data for ACGL saved successfully.
# Data for ACGLN saved successfully.
# Data for ACGLO saved successfully.
# Data for ACHC saved successfully.
# Data for ACHL saved successfully.
# Data for ACHR saved successfully.
# Data for ACHV saved successfully.
# Data for ACI saved successfully.
# Data for ACIC saved successfully.
# Data for ACIU saved successfully.
# Data for ACIW saved successfully.
# Data for ACLS saved successfully.
# Data for ACLX saved successfully.
# Data for ACM saved successfully.
# Data for ACMR saved successfully.
# Data for ACN saved successfully.
# Data for ACNB saved successfully.
# Data for ACNT saved successfully.
# Data for ACON saved successfully.
# Data for ACONW saved successfully.
# Data for ACP saved successfully.
# Data for ACP^A saved successfully.
# Data for ACR saved successfully.
# Data for ACR^C saved successfully.
# Data for ACR^D saved successfully.
# Data for ACRE saved successfully.
# Data for ACRS saved successfully.
# Data for ACRV saved successfully.
# Data for ACST saved successfully.
# Data for ACT saved successfully.
# Data for ACTG saved successfully.
# Data for ACU saved successfully.
# Data for ACV saved successfully.
# Data for ACVA saved successfully.
# Data for ACXP saved successfully.
# Data for ADAG saved successfully.
# Data for ADAP saved successfully.
# Data for ADBE saved successfully.
# Data for ADC saved successfully.
# Data for ADC^A saved successfully.
# Data for ADCT saved successfully.
# Data for ADD saved successfully.
# Data for ADEA saved successfully.
# Data for ADI saved successfully.
# Data for ADIL saved successfully.
# Data for ADM saved successfully.
# Data for ADMA saved successfully.
# Data for ADN saved successfully.
# Data for ADNT saved successfully.
# Data for ADNWW saved successfully.
# Data for ADP saved successfully.
# Data for ADPT saved successfully.
# Data for ADRT saved successfully.
# Data for ADSE saved successfully.
# Data for ADSEW saved successfully.
# Data for ADSK saved successfully.
# Data for ADT saved successfully.
# Data for ADTH saved successfully.
# Data for ADTHW saved successfully.
# Data for ADTN saved successfully.
# Data for ADTX saved successfully.
# Data for ADUS saved successfully.
# Data for ADV saved successfully.
# Data for ADVM saved successfully.
# Data for ADVWW saved successfully.
# Data for ADX saved successfully.
# Data for ADXN saved successfully.
# Data for AE saved successfully.
# Data for AEAE saved successfully.
# Data for AEAEW saved successfully.
# Data for AEE saved successfully.
# Data for AEF saved successfully.
# Data for AEFC saved successfully.
# Data for AEG saved successfully.
# Data for AEHL saved successfully.
# Data for AEHR saved successfully.
# Data for AEI saved successfully.
# Data for AEIS saved successfully.
# Data for AEM saved successfully.
# Data for AEMD saved successfully.
# Data for AENT saved successfully.
# Data for AENTW saved successfully.
# Data for AEO saved successfully.
# Data for AEON saved successfully.
# Data for AEP saved successfully.
# Data for AER saved successfully.
# Data for AERT saved successfully.
# Data for AERTW saved successfully.
# Data for AES saved successfully.
# Data for AESI saved successfully.
# Data for AEVA saved successfully.
# Data for AEYE saved successfully.
# Data for AEZS saved successfully.
# Data for AFAR saved successfully.
# Data for AFARW saved successfully.
# Data for AFB saved successfully.
# Data for AFBI saved successfully.
# Data for AFCG saved successfully.
# Data for AFG saved successfully.
# Data for AFGB saved successfully.
# Data for AFGC saved successfully.
# Data for AFGD saved successfully.
# Data for AFGE saved successfully.
# Data for AFJK saved successfully.
# Data for AFJKU saved successfully.
# Data for AFL saved successfully.
# Data for AFMD saved successfully.
# Data for AFRI saved successfully.
# Data for AFRIW saved successfully.
# Data for AFRM saved successfully.
# Data for AFT saved successfully.
# Data for AFYA saved successfully.
# Data for AG saved successfully.
# Data for AGAE saved successfully.
# Data for AGBA saved successfully.
# Data for AGBAW saved successfully.
# Data for AGCO saved successfully.
# Data for AGD saved successfully.
# Data for AGEN saved successfully.
# Data for AGFY saved successfully.
# Data for AGI saved successfully.
# Data for AGIO saved successfully.
# Data for AGL saved successfully.
# Data for AGM saved successfully.
# Data for AGM^C saved successfully.
# Data for AGM^D saved successfully.
# Data for AGM^E saved successfully.
# Data for AGM^F saved successfully.
# Data for AGM^G saved successfully.
# Data for AGMH saved successfully.
# Data for AGNC saved successfully.
# Data for AGNCL saved successfully.
# Data for AGNCM saved successfully.
# Data for AGNCN saved successfully.
# Data for AGNCO saved successfully.
# Data for AGNCP saved successfully.
# Data for AGO saved successfully.
# Data for AGR saved successfully.
# Data for AGRI saved successfully.
# Data for AGRIW saved successfully.
# Data for AGRO saved successfully.
# Data for AGS saved successfully.
# Data for AGX saved successfully.
# Data for AGYS saved successfully.
# Data for AHCO saved successfully.
# Data for AHG saved successfully.
# Data for AHH saved successfully.
# Data for AHH^A saved successfully.
# Data for AHL^C saved successfully.
# Data for AHL^D saved successfully.
# Data for AHL^E saved successfully.
# Data for AHR saved successfully.
# Data for AHT saved successfully.
# Data for AHT^D saved successfully.
# Data for AHT^F saved successfully.
# Data for AHT^G saved successfully.
# Data for AHT^H saved successfully.
# Data for AHT^I saved successfully.
# Data for AI saved successfully.
# Data for AIF saved successfully.
# Data for AIG saved successfully.
# Data for AIHS saved successfully.
# Data for AILE saved successfully.
# Data for AILEW saved successfully.
# Data for AIM saved successfully.
# Data for AIMAW saved successfully.
# Data for AIMD saved successfully.
# Data for AIMDW saved successfully.
# Data for AIN saved successfully.
# Data for AINC saved successfully.
# Data for AIO saved successfully.
# Data for AIP saved successfully.
# Data for AIR saved successfully.
# Data for AIRC saved successfully.
# Data for AIRE saved successfully.
# Data for AIRG saved successfully.
# Data for AIRI saved successfully.
# Data for AIRJ saved successfully.
# Data for AIRJW saved successfully.
# Data for AIRS saved successfully.
# Data for AIRT saved successfully.
# Data for AIRTP saved successfully.
# Data for AISP saved successfully.
# Data for AISPW saved successfully.
# Data for AIT saved successfully.
# Data for AITR saved successfully.
# Data for AITRR saved successfully.
# Data for AITRU saved successfully.
# Data for AIU saved successfully.
# Data for AIV saved successfully.
# Data for AIXI saved successfully.
# Data for AIZ saved successfully.
# Data for AIZN saved successfully.
# Data for AJG saved successfully.
# Data for AJX saved successfully.
# Data for AKA saved successfully.
# Data for AKAM saved successfully.
# Data for AKAN saved successfully.
# Data for AKBA saved successfully.
# Data for AKLI saved successfully.
# Error fetching data for tickers: Cannot save file into a non-existent directory: 'ticker_data\AKO'
# Fetching data for tickers: ['ARQQ', 'ARQQW', 'ARQT', 'ARR', 'ARR^C', 'ARRY', 'ARTL', 'ARTLW', 'ARTNA', 'ARTW', 'ARVN', 'ARW', 'ARWR', 'ARYD', 'AS', 'ASA', 'ASAI', 'ASAN', 'ASB', 'ASB^E', 'ASB^F', 'ASBA', 'ASC', 'ASCB', 'ASCBW', 'ASG', 'ASGI', 'ASGN', 'ASH', 'ASIX', 'ASLE', 'ASLN', 'ASM', 'ASMB', 'ASML', 'ASND', 'ASNS', 'ASO', 'ASPI', 'ASPN', 'ASPS', 'ASR', 'ASRT', 'ASRV', 'ASST', 'ASTC', 'ASTE', 'ASTH', 'ASTI', 'ASTL', 'ASTLW', 'ASTR', 'ASTS', 'ASTSW', 'ASUR', 'ASX', 'ASXC', 'ASY
# [**********************95%%********************  ]  475 of 500 completedFailed to get ticker 'BF/A' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  500 of 500 completed
#
# 74 Failed downloads:
# ['BENFW', 'BCSAW', 'BLACR', 'BHACW', 'BNAIW', 'BAERW', 'AUROW', 'BLDEW', 'BLEUW', 'BFIIW', 'BCTXW', 'BNZIW', 'BCGWW', 'ATNFW', 'ASTLW', 'BKHAR', 'AVPTW', 'ARTLW', 'BCDAW', 'ASTSW', 'ASCBW', 'BIAFW', 'BETRW', 'ATMCW', 'AWINW', 'BFRGW', 'BEATW', 'BLEUR', 'AUUDW', 'ATMCR', 'ATMVR', 'BNIXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ['BC^A', 'BFS^E', 'BAC^B', 'BML^H', 'ARR^C', 'ASB^E', 'BAC^P', 'BIP^A', 'BEP^A', 'BHR^B', 'AUB^A', 'BAC^K', 'ASB^F', 'ATCO^D', 'BC^B', 'BIP^B', 'BANC^F', 'ATCO^H', 'AULT^D', 'BAC^Q', 'BAC^L', 'BFS^D', 'ATH^C', 'BML^J', 'ATH^B', 'BHR^D', 'BAC^S', 'BML^L', 'BAC^N', 'AXS^E', 'BAC^O', 'BAC^M', 'BF/B', 'ATH^E', 'BCV^A', 'BAC^E', 'BIO/B', 'BML^G', 'ATH^A', 'ATH^D', 'BF/A', 'BC^C']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Data for ARQQ saved successfully.
# Data for ARQQW saved successfully.
# Data for ARQT saved successfully.
# Data for ARR saved successfully.
# Data for ARR^C saved successfully.
# Data for ARRY saved successfully.
# Data for ARTL saved successfully.
# Data for ARTLW saved successfully.
# Data for ARTNA saved successfully.
# Data for ARTW saved successfully.
# Data for ARVN saved successfully.
# Data for ARW saved successfully.
# Data for ARWR saved successfully.
# Data for ARYD saved successfully.
# Data for AS saved successfully.
# Data for ASA saved successfully.
# Data for ASAI saved successfully.
# Data for ASAN saved successfully.
# Data for ASB saved successfully.
# Data for ASB^E saved successfully.
# Data for ASB^F saved successfully.
# Data for ASBA saved successfully.
# Data for ASC saved successfully.
# Data for ASCB saved successfully.
# Data for ASCBW saved successfully.
# Data for ASG saved successfully.
# Data for ASGI saved successfully.
# Data for ASGN saved successfully.
# Data for ASH saved successfully.
# Data for ASIX saved successfully.
# Data for ASLE saved successfully.
# Data for ASLN saved successfully.
# Data for ASM saved successfully.
# Data for ASMB saved successfully.
# Data for ASML saved successfully.
# Data for ASND saved successfully.
# Data for ASNS saved successfully.
# Data for ASO saved successfully.
# Data for ASPI saved successfully.
# Data for ASPN saved successfully.
# Data for ASPS saved successfully.
# Data for ASR saved successfully.
# Data for ASRT saved successfully.
# Data for ASRV saved successfully.
# Data for ASST saved successfully.
# Data for ASTC saved successfully.
# Data for ASTE saved successfully.
# Data for ASTH saved successfully.
# Data for ASTI saved successfully.
# Data for ASTL saved successfully.
# Data for ASTLW saved successfully.
# Data for ASTR saved successfully.
# Data for ASTS saved successfully.
# Data for ASTSW saved successfully.
# Data for ASUR saved successfully.
# Data for ASX saved successfully.
# Data for ASXC saved successfully.
# Data for ASYS saved successfully.
# Data for ATAI saved successfully.
# Data for ATAT saved successfully.
# Data for ATCH saved successfully.
# Data for ATCO^D saved successfully.
# Data for ATCO^H saved successfully.
# Data for ATCOL saved successfully.
# Data for ATEC saved successfully.
# Data for ATEK saved successfully.
# Data for ATEN saved successfully.
# Data for ATER saved successfully.
# Data for ATEX saved successfully.
# Data for ATGE saved successfully.
# Data for ATGL saved successfully.
# Data for ATH^A saved successfully.
# Data for ATH^B saved successfully.
# Data for ATH^C saved successfully.
# Data for ATH^D saved successfully.
# Data for ATH^E saved successfully.
# Data for ATHA saved successfully.
# Data for ATHE saved successfully.
# Data for ATHM saved successfully.
# Data for ATHS saved successfully.
# Data for ATI saved successfully.
# Data for ATIF saved successfully.
# Data for ATIP saved successfully.
# Data for ATKR saved successfully.
# Data for ATLC saved successfully.
# Data for ATLCL saved successfully.
# Data for ATLCP saved successfully.
# Data for ATLCZ saved successfully.
# Data for ATLO saved successfully.
# Data for ATLX saved successfully.
# Data for ATMC saved successfully.
# Data for ATMCR saved successfully.
# Data for ATMCW saved successfully.
# Data for ATMU saved successfully.
# Data for ATMVR saved successfully.
# Data for ATMVU saved successfully.
# Data for ATNF saved successfully.
# Data for ATNFW saved successfully.
# Data for ATNI saved successfully.
# Data for ATNM saved successfully.
# Data for ATO saved successfully.
# Data for ATOM saved successfully.
# Data for ATOS saved successfully.
# Data for ATPC saved successfully.
# Data for ATR saved successfully.
# Data for ATRA saved successfully.
# Data for ATRC saved successfully.
# Data for ATRI saved successfully.
# Data for ATRO saved successfully.
# Data for ATS saved successfully.
# Data for ATSG saved successfully.
# Data for ATUS saved successfully.
# Data for ATXG saved successfully.
# Data for ATXI saved successfully.
# Data for ATXS saved successfully.
# Data for ATYR saved successfully.
# Data for AU saved successfully.
# Data for AUB saved successfully.
# Data for AUB^A saved successfully.
# Data for AUBN saved successfully.
# Data for AUDC saved successfully.
# Data for AUGX saved successfully.
# Data for AUID saved successfully.
# Data for AULT saved successfully.
# Data for AULT^D saved successfully.
# Data for AUMN saved successfully.
# Data for AUNA saved successfully.
# Data for AUPH saved successfully.
# Data for AUR saved successfully.
# Data for AURA saved successfully.
# Data for AUROW saved successfully.
# Data for AUST saved successfully.
# Data for AUTL saved successfully.
# Data for AUUD saved successfully.
# Data for AUUDW saved successfully.
# Data for AVA saved successfully.
# Data for AVAH saved successfully.
# Data for AVAL saved successfully.
# Data for AVAV saved successfully.
# Data for AVB saved successfully.
# Data for AVBP saved successfully.
# Data for AVD saved successfully.
# Data for AVDL saved successfully.
# Data for AVDX saved successfully.
# Data for AVGO saved successfully.
# Data for AVGR saved successfully.
# Data for AVIR saved successfully.
# Data for AVK saved successfully.
# Data for AVNS saved successfully.
# Data for AVNT saved successfully.
# Data for AVNW saved successfully.
# Data for AVO saved successfully.
# Data for AVPT saved successfully.
# Data for AVPTW saved successfully.
# Data for AVRO saved successfully.
# Data for AVT saved successfully.
# Data for AVTE saved successfully.
# Data for AVTR saved successfully.
# Data for AVTX saved successfully.
# Data for AVXL saved successfully.
# Data for AVY saved successfully.
# Data for AWF saved successfully.
# Data for AWH saved successfully.
# Data for AWI saved successfully.
# Data for AWIN saved successfully.
# Data for AWINW saved successfully.
# Data for AWK saved successfully.
# Data for AWP saved successfully.
# Data for AWR saved successfully.
# Data for AWRE saved successfully.
# Data for AWX saved successfully.
# Data for AX saved successfully.
# Data for AXDX saved successfully.
# Data for AXGN saved successfully.
# Data for AXIL saved successfully.
# Data for AXL saved successfully.
# Data for AXNX saved successfully.
# Data for AXON saved successfully.
# Data for AXP saved successfully.
# Data for AXR saved successfully.
# Data for AXS saved successfully.
# Data for AXS^E saved successfully.
# Data for AXSM saved successfully.
# Data for AXTA saved successfully.
# Data for AXTI saved successfully.
# Data for AY saved successfully.
# Data for AYI saved successfully.
# Data for AYRO saved successfully.
# Data for AYTU saved successfully.
# Data for AZ saved successfully.
# Data for AZEK saved successfully.
# Data for AZN saved successfully.
# Data for AZO saved successfully.
# Data for AZPN saved successfully.
# Data for AZTA saved successfully.
# Data for AZTR saved successfully.
# Data for AZUL saved successfully.
# Data for AZZ saved successfully.
# Data for B saved successfully.
# Data for BA saved successfully.
# Data for BABA saved successfully.
# Data for BAC saved successfully.
# Data for BAC^B saved successfully.
# Data for BAC^E saved successfully.
# Data for BAC^K saved successfully.
# Data for BAC^L saved successfully.
# Data for BAC^M saved successfully.
# Data for BAC^N saved successfully.
# Data for BAC^O saved successfully.
# Data for BAC^P saved successfully.
# Data for BAC^Q saved successfully.
# Data for BAC^S saved successfully.
# Data for BACA saved successfully.
# Data for BACK saved successfully.
# Data for BAER saved successfully.
# Data for BAERW saved successfully.
# Data for BAFN saved successfully.
# Data for BAH saved successfully.
# Data for BAK saved successfully.
# Data for BALL saved successfully.
# Data for BALY saved successfully.
# Data for BAM saved successfully.
# Data for BANC saved successfully.
# Data for BANC^F saved successfully.
# Data for BAND saved successfully.
# Data for BANF saved successfully.
# Data for BANFP saved successfully.
# Data for BANL saved successfully.
# Data for BANR saved successfully.
# Data for BANX saved successfully.
# Data for BAOS saved successfully.
# Data for BAP saved successfully.
# Data for BARK saved successfully.
# Data for BASE saved successfully.
# Data for BATL saved successfully.
# Data for BATRA saved successfully.
# Data for BATRK saved successfully.
# Data for BAX saved successfully.
# Data for BAYA saved successfully.
# Data for BAYAU saved successfully.
# Data for BB saved successfully.
# Data for BBAI saved successfully.
# Data for BBAR saved successfully.
# Data for BBCP saved successfully.
# Data for BBD saved successfully.
# Data for BBDC saved successfully.
# Data for BBDO saved successfully.
# Data for BBGI saved successfully.
# Data for BBIO saved successfully.
# Data for BBLG saved successfully.
# Data for BBLGW saved successfully.
# Data for BBN saved successfully.
# Data for BBSI saved successfully.
# Data for BBU saved successfully.
# Data for BBUC saved successfully.
# Data for BBVA saved successfully.
# Data for BBW saved successfully.
# Data for BBWI saved successfully.
# Data for BBY saved successfully.
# Data for BC saved successfully.
# Data for BC^A saved successfully.
# Data for BC^B saved successfully.
# Data for BC^C saved successfully.
# Data for BCAB saved successfully.
# Data for BCAL saved successfully.
# Data for BCAN saved successfully.
# Data for BCAT saved successfully.
# Data for BCBP saved successfully.
# Data for BCC saved successfully.
# Data for BCDA saved successfully.
# Data for BCDAW saved successfully.
# Data for BCE saved successfully.
# Data for BCG saved successfully.
# Data for BCGWW saved successfully.
# Data for BCH saved successfully.
# Data for BCLI saved successfully.
# Data for BCML saved successfully.
# Data for BCO saved successfully.
# Data for BCOV saved successfully.
# Data for BCOW saved successfully.
# Data for BCPC saved successfully.
# Data for BCRX saved successfully.
# Data for BCS saved successfully.
# Data for BCSA saved successfully.
# Data for BCSAU saved successfully.
# Data for BCSAW saved successfully.
# Data for BCSF saved successfully.
# Data for BCTX saved successfully.
# Data for BCTXW saved successfully.
# Data for BCV saved successfully.
# Data for BCV^A saved successfully.
# Data for BCX saved successfully.
# Data for BCYC saved successfully.
# Data for BDC saved successfully.
# Data for BDJ saved successfully.
# Data for BDL saved successfully.
# Data for BDN saved successfully.
# Data for BDRX saved successfully.
# Data for BDSX saved successfully.
# Data for BDTX saved successfully.
# Data for BDX saved successfully.
# Data for BE saved successfully.
# Data for BEAM saved successfully.
# Data for BEAT saved successfully.
# Data for BEATW saved successfully.
# Data for BECN saved successfully.
# Data for BEDU saved successfully.
# Data for BEEM saved successfully.
# Data for BEEP saved successfully.
# Data for BEKE saved successfully.
# Data for BELFA saved successfully.
# Data for BELFB saved successfully.
# Data for BEN saved successfully.
# Data for BENF saved successfully.
# Data for BENFW saved successfully.
# Data for BEP saved successfully.
# Data for BEP^A saved successfully.
# Data for BEPC saved successfully.
# Data for BEPH saved successfully.
# Data for BEPI saved successfully.
# Data for BEPJ saved successfully.
# Data for BERY saved successfully.
# Data for BEST saved successfully.
# Data for BETR saved successfully.
# Data for BETRW saved successfully.
# Error fetching data for tickers: Cannot save file into a non-existent directory: 'ticker_data\BF'
# Fetching data for tickers: ['BOCNW', 'BODI', 'BOE', 'BOF', 'BOH', 'BOH^A', 'BOKF', 'BOLD', 'BOLT', 'BON', 'BOOM', 'BOOT', 'BORR', 'BOSC', 'BOTJ', 'BOW', 'BOWL', 'BOWN', 'BOWNR', 'BOWNU', 'BOX', 'BOXL', 'BP', 'BPMC', 'BPOP', 'BPOPM', 'BPRN', 'BPT', 'BPTH', 'BPYPM', 'BPYPN', 'BPYPO', 'BPYPP', 'BQ', 'BR', 'BRACR', 'BRAG', 'BRBR', 'BRBS', 'BRC', 'BRCC', 'BRDG', 'BREA', 'BRFH', 'BRFS', 'BRID', 'BRK/A', 'BRK/B', 'BRKH', 'BRKHU', 'BRKHW', 'BRKL', 'BRKR', 'BRLS', 'BRLSW', 'BRLT', 'BRN', 'BRNS', 'BRO', 'BROG', 'BROGW', 'BROS', 'BRSH', 'BRSHW', 'BRSP', 'BRT', 'BRTX', 'BRW', 'BRX', 'BRY', 'BRZE', 'BSAC', 'BSBK', 'BSBR', 'BSET', 'BSFC', 'BSGM', 'BSIG', 'BSL', 'BSM', 'BSRR', 'BST', 'BSTZ', 'BSVN', 'BSX', 'BSY', 'BTA', 'BTAI', 'BTBD', 'BTBDW', 'BTBT',
', 'CFB', 'CFBK', 'CFFI', 'CFFN', 'CFFS', 'CFG', 'CFG^D', 'CFG^E', 'CFG^H', 'CFLT', 'CFR', 'CFR^B', 'CFSB', 'CG', 'CGA', 'CGABL', 'CGAU', 'CGBD', 'CGBDL', 'CGC', 'CGEM', 'CGEN', 'CGNT', 'CGNX', 'CGO', 'CGON', 'CGTX', 'CHAA', 'CHCI', 'CHCO', 'CHCT', 'CHD', 'CHDN', 'CHE', 'CHEF', 'CHEK', 'CHGG', 'CHH', 'CHI', 'CHK', 'CHKEL', 'CHKEW', 'CHKEZ', 'CHKP', 'CHMG', 'CHMI', 'CHMI^A', 'CHMI^B', 'CHN', 'CHNR', 'CHPT', 'CHR', 'CHRD', 'CHRO', 'CHRS', 'CHRW', 'CHSCL', 'CHSCM', 'CHSCN', 'CHSCO', 'CHSCP', 'CHSN', 'CHT', 'CHTR', 'CHUY', 'CHW', 'CHWY', 'CHX', 'CHY', 'CI', 'CIA', 'CIB', 'CIEN', 'CIF', 'CIFR', 'CIFRW', 'CIG', 'CIGI', 'CII', 'CIK', 'CIM', 'CIM^A', 'CIM^B', 'CIM^C', 'CIM^D', 'CIMN', 'CINF', 'CING', 'CINGW', 'CINT', 'CIO', 'CIO^A', 'CION', 'CISO', 'CISS', 'CITE', 'CIVB', 'CIVI', 'CIX', 'CJET', 'CJJD', 'CKPT', 'CKX', 'CL', 'CLAR', 'CLB', 'CLBK', 'CLBR', 'CLBT', 'CLBTW', 'CLCO', 'CLDI', 'CLDT', 'CLDT^A', 'CLDX', 'CLEU', 'CLF', 'CLFD', 'CLGN', 'CLH', 'CLIR', 'CLLS', 'CLM', 'CLMB', 'CLMT', 'CLNE', 'CLNN', 'CLNNW', 'CLOE', 'CLOER', 'CLOV', 'CLPR', 'CLPS', 'CLPT', 'CLRB', 'CLRC', 'CLRCR', 'CLRCW', 'CLRO', 'CLS', 'CLSD', 'CLSK', 'CLST', 'CLVT', 'CLW', 'CLWT', 'CLX', 'CM', 'CMA', 'CMAX', 'CMAXW', 'CMBM', 'CMC', 'CMCA', 'CMCAW', 'CMCL', 'CMCM', 'CMCO', 'CMCSA', 'CMCT', 'CME', 'CMG', 'CMI', 'CMLS', 'CMMB', 'CMND', 'CMP', 'CMPO', 'CMPOW', 'CMPR', 'CMPS', 'CMPX']
# [**********************60%%***                   ]  302 of 500 completedFailed to get ticker 'BRK/B' reason: Expecting value: line 1 column 1 (char 0)
# [**********************62%%****                  ]  310 of 500 completedFailed to get ticker 'BRK/A' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  500 of 500 completed
#
# 56 Failed downloads:
# ['CMCAW', 'CLNNW', 'BROGW', 'CLRCW', 'CMAXW', 'CELUW', 'BTCTW', 'BRSHW', 'CCTSW', 'BWAQR', 'CDTTW', 'BWAQW', 'BOCNW', 'CDROW', 'CETUW', 'CDIOW', 'BZFDW', 'CLOER', 'BOWNR', 'BTBDW', 'BRKHW', 'CIFRW', 'CLBTW', 'BTMWW', 'BYNOW', 'CLRCR', 'BRLSW', 'CETUR', 'CEADW', 'BUJAR', 'BRACR', 'CDAQW', 'CAPTW', 'CMPOW', 'CEROW', 'CINGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ['CFG^D', 'BOH^A', 'CIM^B', 'CLDT^A', 'CDR^C', 'C^N', 'BW^A', 'CADE^A', 'BRK/B', 'BRK/A', 'CHMI^A', 'CIO^A', 'CIM^A', 'CFG^E', 'CHMI^B', 'CFG^H', 'CIM^C', 'CIM^D', 'CFR^B', 'CDR^B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Data for BOCNW saved successfully.
# Data for BODI saved successfully.
# Data for BOE saved successfully.
# Data for BOF saved successfully.
# Data for BOH saved successfully.
# Data for BOH^A saved successfully.
# Data for BOKF saved successfully.
# Data for BOLD saved successfully.
# Data for BOLT saved successfully.
# Data for BON saved successfully.
# Data for BOOM saved successfully.
# Data for BOOT saved successfully.
# Data for BORR saved successfully.
# Data for BOSC saved successfully.
# Data for BOTJ saved successfully.
# Data for BOW saved successfully.
# Data for BOWL saved successfully.
# Data for BOWN saved successfully.
# Data for BOWNR saved successfully.
# Data for BOWNU saved successfully.
# Data for BOX saved successfully.
# Data for BOXL saved successfully.
# Data for BP saved successfully.
# Data for BPMC saved successfully.
# Data for BPOP saved successfully.
# Data for BPOPM saved successfully.
# Data for BPRN saved successfully.
# Data for BPT saved successfully.
# Data for BPTH saved successfully.
# Data for BPYPM saved successfully.
# Data for BPYPN saved successfully.
# Data for BPYPO saved successfully.
# Data for BPYPP saved successfully.
# Data for BQ saved successfully.
# Data for BR saved successfully.
# Data for BRACR saved successfully.
# Data for BRAG saved successfully.
# Data for BRBR saved successfully.
# Data for BRBS saved successfully.
# Data for BRC saved successfully.
# Data for BRCC saved successfully.
# Data for BRDG saved successfully.
# Data for BREA saved successfully.
# Data for BRFH saved successfully.
# Data for BRFS saved successfully.
# [                       0%%                      ]
# Data for BRID saved successfully.
# Error fetching data for tickers: Cannot save file into a non-existent directory: 'ticker_data\BRK'
# Fetching data for tickers: ['CMRE', 'CMRE^B', 'CMRE^C', 'CMRE^D', 'CMRE^E', 'CMRX', 'CMS', 'CMS^B', 'CMS^C', 'CMSA', 'CMSC', 'CMSD', 'CMT', 'CMTG', 'CMTL', 'CMU', 'CNA', 'CNC', 'CNDA', 'CNDT', 'CNET', 'CNEY', 'CNF', 'CNFR', 'CNFRZ', 'CNGL', 'CNGLU', 'CNGLW', 'CNH', 'CNI', 'CNK', 'CNM', 'CNMD', 'CNNE', 'CNO', 'CNO^A', 'CNOB', 'CNOBP', 'CNP', 'CNQ', 'CNS', 'CNSL', 'CNSP', 'CNTA', 'CNTB', 'CNTG', 'CNTX', 'CNTY', 'CNVS', 'CNX', 'CNXC', 'CNXN', 'COCH', 'COCO', 'COCP', 'CODA', 'CODI', 'CODI^A', 'CODI^B', 'CODI^C', 'CODX', 'COE', 'COEP', 'COEPW', 'COF', 'COF^I', 'COF^J', 'COF^K', 'COF^L', 'COF^N', 'COFS', 'COGT', 'COHN', 'COHR', 'COHU', 'COIN', 'COKE',
# ['CMRE^C', 'COF^K', 'DLR^L', 'CMS^C', 'CMRE^D', 'COF^I', 'CSR^C', 'DLNG^B', 'CRD/B', 'CMS^B', 'DLR^K', 'DBRG^H', 'CODI^C', 'DLR^J', 'CTA^B', 'DBRG^I', 'CUBI^F', 'COF^L', 'CMRE^B', 'CMRE^E', 'CUBI^E', 'CNO^A', 'COF^N', 'CTO^A', 'CODI^B', 'DRH^A', 'DLNG^A', 'CRD/A', 'COF^J', 'CTA^A', 'CODI^A', 'DBRG^J']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Data for CMRE saved successfully.
# Data for CMRE^B saved successfully.
# Data for CMRE^C saved successfully.
# Data for CMRE^D saved successfully.
# Data for CMRE^E saved successfully.
# Data for CMRX saved successfully.
# Data for CMS saved successfully.
# Data for CMS^B saved successfully.
# Data for CMS^C saved successfully.
# Data for CMSA saved successfully.
# Data for CMSC saved successfully.
# Data for CMSD saved successfully.
# Data for CMT saved successfully.
# Data for CMTG saved successfully.
# Data for CMTL saved successfully.
# Data for CMU saved successfully.
# Data for CNA saved successfully.
# Data for CNC saved successfully.
# Data for CNDA saved successfully.
# Data for CNDT saved successfully.
# Data for CNET saved successfully.
# Data for CNEY saved successfully.
# Data for CNF saved successfully.
# Data for CNFR saved successfully.
# Data for CNFRZ saved successfully.
# Data for CNGL saved successfully.
# Data for CNGLU saved successfully.
# Data for CNGLW saved successfully.
# Data for CNH saved successfully.
# Data for CNI saved successfully.
# Data for CNK saved successfully.
# Data for CNM saved successfully.
# Data for CNMD saved successfully.
# Data for CNNE saved successfully.
# Data for CNO saved successfully.
# Data for CNO^A saved successfully.
# Data for CNOB saved successfully.
# Data for CNOBP saved successfully.
# Data for CNP saved successfully.
# Data for CNQ saved successfully.
# Data for CNS saved successfully.
# Data for CNSL saved successfully.
# Data for CNSP saved successfully.
# Data for CNTA saved successfully.
# Data for CNTB saved successfully.
# Data for CNTG saved successfully.
# Data for CNTX saved successfully.
# Data for CNTY saved successfully.
# Data for CNVS saved successfully.
# Data for CNX saved successfully.
# Data for CNXC saved successfully.
# Data for CNXN saved successfully.
# Data for COCH saved successfully.
# Data for COCO saved successfully.
# Data for COCP saved successfully.
# Data for CODA saved successfully.
# Data for CODI saved successfully.
# Data for CODI^A saved successfully.
# Data for CODI^B saved successfully.
# Data for CODI^C saved successfully.
# Data for CODX saved successfully.
# Data for COE saved successfully.
# Data for COEP saved successfully.
# Data for COEPW saved successfully.
# Data for COF saved successfully.
# Data for COF^I saved successfully.
# Data for COF^J saved successfully.
# Data for COF^K saved successfully.
# Data for COF^L saved successfully.
# Data for COF^N saved successfully.
# Data for COFS saved successfully.
# Data for COGT saved successfully.
# Data for COHN saved successfully.
# Data for COHR saved successfully.
# Data for COHU saved successfully.
# Data for COIN saved successfully.
# Data for COKE saved successfully.
# Data for COLB saved successfully.
# Data for COLD saved successfully.
# Data for COLL saved successfully.
# Data for COLM saved successfully.
# Data for COMM saved successfully.
# Data for COMP saved successfully.
# Data for CONN saved successfully.
# Data for COO saved successfully.
# Data for COOK saved successfully.
# Data for COOL saved successfully.
# Data for COOLU saved successfully.
# Data for COOLW saved successfully.
# Data for COOP saved successfully.
# Data for COOT saved successfully.
# Data for COOTW saved successfully.
# Data for COP saved successfully.
# Data for COR saved successfully.
# Data for CORT saved successfully.
# Data for CORZ saved successfully.
# Data for CORZW saved successfully.
# Data for CORZZ saved successfully.
# Data for COSM saved successfully.
# Data for COST saved successfully.
# Data for COTY saved successfully.
# Data for COUR saved successfully.
# Data for COYA saved successfully.
# Data for CP saved successfully.
# Data for CPA saved successfully.
# Data for CPAC saved successfully.
# Data for CPAY saved successfully.
# Data for CPB saved successfully.
# Data for CPBI saved successfully.
# Data for CPF saved successfully.
# Data for CPHC saved successfully.
# Data for CPHI saved successfully.
# Data for CPIX saved successfully.
# Data for CPK saved successfully.
# Data for CPLP saved successfully.
# Data for CPNG saved successfully.
# Data for CPOP saved successfully.
# Data for CPRI saved successfully.
# Data for CPRT saved successfully.
# Data for CPRX saved successfully.
# Data for CPS saved successfully.
# Data for CPSH saved successfully.
# Data for CPSS saved successfully.
# Data for CPT saved successfully.
# Data for CPTN saved successfully.
# Data for CPTNW saved successfully.
# Data for CPZ saved successfully.
# Data for CQP saved successfully.
# Data for CR saved successfully.
# Data for CRAI saved successfully.
# Data for CRBG saved successfully.
# Data for CRBP saved successfully.
# Data for CRBU saved successfully.
# Data for CRC saved successfully.
# Data for CRCT saved successfully.
# Error fetching data for tickers: Cannot save file into a non-existent directory: 'ticker_data\CRD'
# ...
# Data for VIR saved successfully.
# Data for VIRC saved successfully.
# Data for VIRI saved successfully.
# Data for VIRT saved successfully.
# Data for VIRX saved successfully.
# Data for VISL saved successfully.
# Data for VIST saved successfully.
# Data for VITL saved successfully.
# Data for VIV saved successfully.
# Data for VIVK saved successfully.
# Data for VKI saved successfully.
# Data for VKQ saved successfully.
# Data for VKTX saved successfully.
# Data for VLCN saved successfully.
# Data for VLD saved successfully.
# Data for VLGEA saved successfully.
# Data for VLN saved successfully.
# Data for VLO saved successfully.
# Data for VLRS saved successfully.
# Data for VLT saved successfully.
# Data for VLTO saved successfully.
# Data for VLY saved successfully.
# Data for VLYPO saved successfully.
# Data for VLYPP saved successfully.
# Data for VMAR saved successfully.
# Data for VMC saved successfully.
# Data for VMCA saved successfully.
# Data for VMCAW saved successfully.
# Data for VMD saved successfully.
# Data for VMEO saved successfully.
# Data for VMI saved successfully.
# Data for VMO saved successfully.
# Data for VNCE saved successfully.
# Data for VNDA saved successfully.
# Data for VNET saved successfully.
# Data for VNO saved successfully.
# Data for VNO^L saved successfully.
# Data for VNO^M saved successfully.
# Data for VNO^N saved successfully.
# Data for VNO^O saved successfully.
# Data for VNOM saved successfully.
# Data for VNRX saved successfully.
# Data for VNT saved successfully.
# Data for VOC saved successfully.
# Data for VOD saved successfully.
# Data for VOR saved successfully.
# Data for VOXR saved successfully.
# Data for VOXX saved successfully.
# Data for VOYA saved successfully.
# Data for VOYA^B saved successfully.
# Data for VPG saved successfully.
# Data for VPV saved successfully.
# Data for VRA saved successfully.
# Data for VRAR saved successfully.
# Data for VRAX saved successfully.
# Data for VRCA saved successfully.
# Data for VRDN saved successfully.
# Data for VRE saved successfully.
# Data for VREX saved successfully.
# Data for VRM saved successfully.
# Data for VRME saved successfully.
# Data for VRMEW saved successfully.
# Data for VRN saved successfully.
# Data for VRNA saved successfully.
# Data for VRNS saved successfully.
# Data for VRNT saved successfully.
# Data for VRPX saved successfully.
# Data for VRRM saved successfully.
# Data for VRSK saved successfully.
# Data for VRSN saved successfully.
# Data for VRT saved successfully.
# Data for VRTS saved successfully.
# Data for VRTX saved successfully.
# Data for VS saved successfully.
# Data for VSAC saved successfully.
# Data for VSACW saved successfully.
# Data for VSAT saved successfully.
# Data for VSCO saved successfully.
# Data for VSEC saved successfully.
# Data for VSH saved successfully.
# Data for VSME saved successfully.
# Data for VSSYW saved successfully.
# Data for VST saved successfully.
# Data for VSTA saved successfully.
# Data for VSTE saved successfully.
# Data for VSTEW saved successfully.
# Data for VSTM saved successfully.
# Data for VSTO saved successfully.
# Data for VSTS saved successfully.
# Data for VTAK saved successfully.
# Data for VTEX saved successfully.
# Data for VTGN saved successfully.
# Data for VTLE saved successfully.
# Data for VTMX saved successfully.
# Data for VTN saved successfully.
# Data for VTNR saved successfully.
# Data for VTOL saved successfully.
# Data for VTR saved successfully.
# Data for VTRS saved successfully.
# Data for VTRU saved successfully.
# Data for VTS saved successfully.
# Data for VTSI saved successfully.
# Data for VTVT saved successfully.
# Data for VTYX saved successfully.
# Data for VUZI saved successfully.
# Data for VVI saved successfully.
# Data for VVOS saved successfully.
# Data for VVPR saved successfully.
# Data for VVR saved successfully.
# Data for VVV saved successfully.
# Data for VVX saved successfully.
# Data for VWE saved successfully.
# Data for VWEWW saved successfully.
# Data for VXRT saved successfully.
# Data for VXX saved successfully.
# Data for VXZ saved successfully.
# Data for VYGR saved successfully.
# Data for VYNE saved successfully.
# Data for VYX saved successfully.
# Data for VZ saved successfully.
# Data for VZIO saved successfully.
# Data for VZLA saved successfully.
# Data for W saved successfully.
# Data for WAB saved successfully.
# Data for WABC saved successfully.
# Data for WAFD saved successfully.
# Data for WAFDP saved successfully.
# Data for WAFU saved successfully.
# Data for WAL saved successfully.
# Data for WAL^A saved successfully.
# Data for WALD saved successfully.
# Data for WALDW saved successfully.
# Data for WASH saved successfully.
# Data for WAT saved successfully.
# Data for WATT saved successfully.
# Data for WAVD saved successfully.
# Data for WAVE saved successfully.
# Data for WAVS saved successfully.
# Data for WAVSU saved successfully.
# Data for WAY saved successfully.
# Data for WB saved successfully.
# Data for WBA saved successfully.
# Data for WBD saved successfully.
# Data for WBS saved successfully.
# Data for WBS^F saved successfully.
# Data for WBS^G saved successfully.
# Data for WBUY saved successfully.
# Data for WBX saved successfully.
# Data for WCC saved successfully.
# Data for WCC^A saved successfully.
# Data for WCN saved successfully.
# Data for WD saved successfully.
# Data for WDAY saved successfully.
# Data for WDC saved successfully.
# Data for WDFC saved successfully.
# Data for WDH saved successfully.
# Data for WDI saved successfully.
# Data for WDS saved successfully.
# Data for WEA saved successfully.
# Data for WEAV saved successfully.
# Data for WEC saved successfully.
# Data for WEL saved successfully.
# Data for WELL saved successfully.
# Data for WEN saved successfully.
# Data for WERN saved successfully.
# Data for WES saved successfully.
# Data for WEST saved successfully.
# Data for WESTW saved successfully.
# Data for WETH saved successfully.
# Data for WEX saved successfully.
# Data for WEYS saved successfully.
# Data for WF saved successfully.
# Data for WFC saved successfully.
# Data for WFC^A saved successfully.
# Data for WFC^C saved successfully.
# Data for WFC^D saved successfully.
# Data for WFC^L saved successfully.
# Data for WFC^Y saved successfully.
# Data for WFC^Z saved successfully.
# Data for WFCF saved successfully.
# Data for WFG saved successfully.
# Data for WFRD saved successfully.
# Data for WGO saved successfully.
# Data for WGS saved successfully.
# Data for WGSWW saved successfully.
# Data for WH saved successfully.
# Data for WHD saved successfully.
# Data for WHF saved successfully.
# Data for WHFCL saved successfully.
# Data for WHG saved successfully.
# Data for WHLM saved successfully.
# Data for WHLR saved successfully.
# Data for WHLRD saved successfully.
# Data for WHLRP saved successfully.
# Data for WHR saved successfully.
# Data for WIA saved successfully.
# Data for WILC saved successfully.
# Data for WIMI saved successfully.
# Data for WINA saved successfully.
# Data for WING saved successfully.
# Data for WINT saved successfully.
# Data for WINV saved successfully.
# Data for WINVU saved successfully.
# Data for WINVW saved successfully.
# Data for WIRE saved successfully.
# Data for WISA saved successfully.
# Data for WIT saved successfully.
# Data for WIW saved successfully.
# Data for WIX saved successfully.
# Data for WK saved successfully.
# Data for WKC saved successfully.
# Data for WKEY saved successfully.
# Data for WKHS saved successfully.
# Data for WKME saved successfully.
# Data for WKSP saved successfully.
# Data for WKSPW saved successfully.
# Data for WLDN saved successfully.
# Data for WLDS saved successfully.
# Data for WLFC saved successfully.
# Data for WLGS saved successfully.
# Data for WLK saved successfully.
# Data for WLKP saved successfully.
# Data for WLY saved successfully.
# Data for WLYB saved successfully.
# Data for WM saved successfully.
# Data for WMB saved successfully.
# Data for WMG saved successfully.
# Data for WMK saved successfully.
# Data for WMPN saved successfully.
# Data for WMS saved successfully.
# Data for WMT saved successfully.
# Data for WNC saved successfully.
# Data for WNEB saved successfully.
# Data for WNS saved successfully.
# Data for WNW saved successfully.
# Data for WOLF saved successfully.
# Data for WOOF saved successfully.
# Data for WOR saved successfully.
# Data for WORX saved successfully.
# Data for WOW saved successfully.
# Data for WPC saved successfully.
# Data for WPM saved successfully.
# Data for WPP saved successfully.
# Data for WPRT saved successfully.
# Data for WRAP saved successfully.
# Data for WRB saved successfully.
# Data for WRB^E saved successfully.
# Data for WRB^F saved successfully.
# Data for WRB^G saved successfully.
# Data for WRB^H saved successfully.
# Data for WRBY saved successfully.
# Data for WRK saved successfully.
# Data for WRLD saved successfully.
# Data for WRN saved successfully.
# Data for WRNT saved successfully.
# Data for WS saved successfully.
# Data for WSBC saved successfully.
# Data for WSBCP saved successfully.
# Data for WSBF saved successfully.
# Data for WSC saved successfully.
# Data for WSFS saved successfully.
# Data for WSM saved successfully.
# Data for WSO saved successfully.
# Error fetching data for tickers: Cannot save file into a non-existent directory: 'ticker_data\WSO'
# Fetching data for tickers: ['WTMA', 'WTMAR', 'WTO', 'WTRG', 'WTS', 'WTTR', 'WTW', 'WU', 'WULF', 'WVE', 'WVVI', 'WVVIP', 'WW', 'WWD', 'WWR', 'WWW', 'WY', 'WYNN', 'WYY', 'X', 'XAIR', 'XBIO', 'XBIOW', 'XBIT', 'XBP', 'XBPEW', 'XCUR', 'XEL', 'XELA', 'XELAP', 'XELB', 'XENE', 'XERS', 'XFIN', 'XFINW', 'XFLT', 'XFLT^A', 'XFOR', 'XGN', 'XHG', 'XHR', 'XIN', 'XLO', 'XMTR', 'XNCR', 'XNET', 'XOM', 'XOMA', 'XOMAO', 'XOMAP', 'XOS', 'XOSWW', 'XP', 'XPEL', 'XPER', 'XPEV', 'XPL', 'XPO', 'XPOF', 'XPON', 'XPRO', 'XRAY', 'XRTX', 'XRX', 'XTIA', 'XTKG', 'XTLB', 'XTNT', 'XWEL', 'XXII', 'XYF', 'XYL', 'XYLO', 'YALA', 'YCBD', 'YCBD^A', 'YELP', 'YETI', 'YEXT', 'YGMZ', 'YHGJ', 'YI', 'YIBO', 'YJ', 'YMAB', 'YMM', 'YORW', 'YOSH', 'YOTA', 'YOTAW', 'YOU', 'YPF', 'YQ', 'YRD', 'YSG', 'YTRA', 'YUM', 'YUMC', 'YY', 'YYAI', 'YYGH', 'Z', 'ZAPP', 'ZAPPW', 'ZBAO', 'ZBH', 'ZBRA', 'ZCAR', 'ZCARW', 'ZCMD', 'ZD', 'ZDGE', 'ZENV', 'ZEO', 'ZEOWW', 'ZEPP', 'ZETA', 'ZEUS', 'ZG', 'ZGN', 'ZH', 'ZI', 'ZIM', 'ZIMV', 'ZION', 'ZIONL', 'ZIONO', 'ZIONP', 'ZIP', 'ZJYL', 'ZK', 'ZKH', 'ZKIN', 'ZLAB', 'ZLS', 'ZLSWW', 'ZM', 'ZNTL', 'ZOM', 'ZONE', 'ZOOZ', 'ZOOZW', 'ZPTA', 'ZPTAW', 'ZS', 'ZTEK', 'ZTO', 'ZTR', 'ZTS', 'ZUMZ', 'ZUO', 'ZURA', 'ZURAW', 'ZVIA', 'ZVRA', 'ZVSA', 'ZWS', 'ZYME', 'ZYXI']
# [*********************100%%**********************]  159 of 159 completed
#
# 14 Failed downloads:
# ['ZEOWW', 'YOTAW', 'ZPTAW', 'ZOOZW', 'ZAPPW', 'ZLSWW', 'ZCARW', 'WTMAR', 'XFINW', 'ZURAW', 'XOSWW', 'XBPEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# ['YCBD^A', 'XFLT^A']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Data for WTMA saved successfully.
# Data for WTMAR saved successfully.
# Data for WTO saved successfully.
# Data for WTRG saved successfully.
# Data for WTS saved successfully.
# Data for WTTR saved successfully.
# Data for WTW saved successfully.
# Data for WU saved successfully.
# Data for WULF saved successfully.
# Data for WVE saved successfully.
# Data for WVVI saved successfully.
# Data for WVVIP saved successfully.
# Data for WW saved successfully.
# Data for WWD saved successfully.
# Data for WWR saved successfully.
# Data for WWW saved successfully.
# Data for WY saved successfully.
# Data for WYNN saved successfully.
# Data for WYY saved successfully.
# Data for X saved successfully.
# Data for XAIR saved successfully.
# Data for XBIO saved successfully.
# Data for XBIOW saved successfully.
# Data for XBIT saved successfully.
# Data for XBP saved successfully.
# Data for XBPEW saved successfully.
# Data for XCUR saved successfully.
# Data for XEL saved successfully.
# Data for XELA saved successfully.
# Data for XELAP saved successfully.
# Data for XELB saved successfully.
# Data for XENE saved successfully.
# Data for XERS saved successfully.
# Data for XFIN saved successfully.
# Data for XFINW saved successfully.
# Data for XFLT saved successfully.
# Data for XFLT^A saved successfully.
# Data for XFOR saved successfully.
# Data for XGN saved successfully.
# Data for XHG saved successfully.
# Data for XHR saved successfully.
# Data for XIN saved successfully.
# Data for XLO saved successfully.
# Data for XMTR saved successfully.
# Data for XNCR saved successfully.
# Data for XNET saved successfully.
# Data for XOM saved successfully.
# Data for XOMA saved successfully.
# Data for XOMAO saved successfully.
# Data for XOMAP saved successfully.
# Data for XOS saved successfully.
# Data for XOSWW saved successfully.
# Data for XP saved successfully.
# Data for XPEL saved successfully.
# Data for XPER saved successfully.
# Data for XPEV saved successfully.
# Data for XPL saved successfully.
# Data for XPO saved successfully.
# Data for XPOF saved successfully.
# Data for XPON saved successfully.
# Data for XPRO saved successfully.
# Data for XRAY saved successfully.
# Data for XRTX saved successfully.
# Data for XRX saved successfully.
# Data for XTIA saved successfully.
# Data for XTKG saved successfully.
# Data for XTLB saved successfully.
# Data for XTNT saved successfully.
# Data for XWEL saved successfully.
# Data for XXII saved successfully.
# Data for XYF saved successfully.
# Data for XYL saved successfully.
# Data for XYLO saved successfully.
# Data for YALA saved successfully.
# Data for YCBD saved successfully.
# Data for YCBD^A saved successfully.
# Data for YELP saved successfully.
# Data for YETI saved successfully.
# Data for YEXT saved successfully.
# Data for YGMZ saved successfully.
# Data for YHGJ saved successfully.
# Data for YI saved successfully.
# Data for YIBO saved successfully.
# Data for YJ saved successfully.
# Data for YMAB saved successfully.
# Data for YMM saved successfully.
# Data for YORW saved successfully.
# Data for YOSH saved successfully.
# Data for YOTA saved successfully.
# Data for YOTAW saved successfully.
# Data for YOU saved successfully.
# Data for YPF saved successfully.
# Data for YQ saved successfully.
# Data for YRD saved successfully.
# Data for YSG saved successfully.
# Data for YTRA saved successfully.
# Data for YUM saved successfully.
# Data for YUMC saved successfully.
# Data for YY saved successfully.
# Data for YYAI saved successfully.
# Data for YYGH saved successfully.
# Data for Z saved successfully.
# Data for ZAPP saved successfully.
# Data for ZAPPW saved successfully.
# Data for ZBAO saved successfully.
# Data for ZBH saved successfully.
# Data for ZBRA saved successfully.
# Data for ZCAR saved successfully.
# Data for ZCARW saved successfully.
# Data for ZCMD saved successfully.
# Data for ZD saved successfully.
# Data for ZDGE saved successfully.
# Data for ZENV saved successfully.
# Data for ZEO saved successfully.
# Data for ZEOWW saved successfully.
# Data for ZEPP saved successfully.
# Data for ZETA saved successfully.
# Data for ZEUS saved successfully.
# Data for ZG saved successfully.
# Data for ZGN saved successfully.
# Data for ZH saved successfully.
# Data for ZI saved successfully.
# Data for ZIM saved successfully.
# Data for ZIMV saved successfully.
# Data for ZION saved successfully.
# Data for ZIONL saved successfully.
# Data for ZIONO saved successfully.
# Data for ZIONP saved successfully.
# Data for ZIP saved successfully.
# Data for ZJYL saved successfully.
# Data for ZK saved successfully.
# Data for ZKH saved successfully.
# Data for ZKIN saved successfully.
# Data for ZLAB saved successfully.
# Data for ZLS saved successfully.
# Data for ZLSWW saved successfully.
# Data for ZM saved successfully.
# Data for ZNTL saved successfully.
# Data for ZOM saved successfully.
# Data for ZONE saved successfully.
# Data for ZOOZ saved successfully.
# Data for ZOOZW saved successfully.
# Data for ZPTA saved successfully.
# Data for ZPTAW saved successfully.
# Data for ZS saved successfully.
# Data for ZTEK saved successfully.
# Data for ZTO saved successfully.
# Data for ZTR saved successfully.
# Data for ZTS saved successfully.
# Data for ZUMZ saved successfully.
# Data for ZUO saved successfully.
# Data for ZURA saved successfully.
# Data for ZURAW saved successfully.
# Data for ZVIA saved successfully.
# Data for ZVRA saved successfully.
# Data for ZVSA saved successfully.
# Data for ZWS saved successfully.
# Data for ZYME saved successfully.
# Data for ZYXI saved successfully.
# Data fetching completed.

# %%
import os
import pandas as pd

def load_and_resample_ticker_data():
    ticker_data_dir = 'ticker_data'
    weekly_data_dir = 'weekly_data'
    
    if not os.path.exists(weekly_data_dir):
        os.makedirs(weekly_data_dir)
    
    # List all CSV files in the ticker_data directory
    ticker_files = [f for f in os.listdir(ticker_data_dir) if f.endswith('.csv')]
    
    # Dictionary to store dataframes for each ticker
    ticker_dataframes = {}
    
    for file in ticker_files:
        # Extract the ticker symbol from the file name (assuming it's the file name without extension)
        ticker_symbol = os.path.splitext(file)[0]
        
        # Load the CSV file into a DataFrame
        df = pd.read_csv(os.path.join(ticker_data_dir, file))
        
        # Ensure the date column is in datetime format
        df['date'] = pd.to_datetime(df['date'])
        
        # Set the date column as the index
        df.set_index('date', inplace=True)
        
        # Store the DataFrame in the dictionary
        ticker_dataframes[ticker_symbol] = df

    # Concatenate all dataframes along the columns axis, aligning on the date index
    combined_df = pd.concat(ticker_dataframes.values(), axis=1, keys=ticker_dataframes.keys())
    
    # Select only numeric columns for resampling
    numeric_combined_df = combined_df.select_dtypes(include='number')
    
    # Resample the combined dataframe to weekly frequency, using the mean for example
    weekly_combined_df = numeric_combined_df.resample('W').mean()
    
    # Iterate over each ticker to save the resampled data back to individual files
    for ticker_symbol in ticker_dataframes.keys():
        # Extract the ticker's resampled data
        ticker_weekly_df = weekly_combined_df[ticker_symbol]
        
        # Reset the index to have the date as a column again
        ticker_weekly_df.reset_index(inplace=True)
        
        # Write the weekly data to a new CSV file in the weekly_data directory
        ticker_weekly_df.to_csv(os.path.join(weekly_data_dir, f'{ticker_symbol}_weekly.csv'), index=False)

# Call the function to execute the task
load_and_resample_ticker_data()

# %%
import os
import pandas as pd

def calculate_rsi(df, column='Close', period=14):
    delta = df[column].diff()
    gain = delta.clip(lower=0).rolling(window=period, min_periods=1).mean()
    loss = -delta.clip(upper=0).rolling(window=period, min_periods=1).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_mfi(df, period=14):
    typical_price = (df['High'] + df['Low'] + df['Close']) / 3
    money_fLow = typical_price * df['Volume']
    positive_fLow = money_fLow.where(typical_price > typical_price.shift(1), 0).rolling(window=period, min_periods=1).sum()
    negative_fLow = money_fLow.where(typical_price < typical_price.shift(1), 0).rolling(window=period, min_periods=1).sum()
    mfi = 100 - (100 / (1 + positive_fLow / negative_fLow))
    return mfi

def calculate_ultimate_oscillator(df, short_period=7, mid_period=14, long_period=28):
    # Ensure the DataFrame is sorted by date
    df = df.sort_index()

    # Calculate Buying Pressure (BP) and True Range (TR)
    df['Prior Close'] = df['Close'].shift(1)
    df['BP'] = df['Close'] - df[['Low', 'Prior Close']].min(axis=1)
    df['TR'] = df[['High', 'Prior Close']].max(axis=1) - df[['Low', 'Prior Close']].min(axis=1)
    
    # Calculate average BP and TR for each period
    df['Avg7_BP'] = df['BP'].rolling(window=short_period).sum()
    df['Avg7_TR'] = df['TR'].rolling(window=short_period).sum()
    df['Avg14_BP'] = df['BP'].rolling(window=mid_period).sum()
    df['Avg14_TR'] = df['TR'].rolling(window=mid_period).sum()
    df['Avg28_BP'] = df['BP'].rolling(window=long_period).sum()
    df['Avg28_TR'] = df['TR'].rolling(window=long_period).sum()
    
    # Calculate raw UO components
    df['R1'] = df['Avg7_BP'] / df['Avg7_TR']
    df['R2'] = df['Avg14_BP'] / df['Avg14_TR']
    df['R3'] = df['Avg28_BP'] / df['Avg28_TR']
    
    # Calculate Ultimate Oscillator
    df['Ultimate Oscillator'] = 100 * (4 * df['R1'] + 2 * df['R2'] + df['R3']) / (4 + 2 + 1)
    
    return df['Ultimate Oscillator']

def calculate_obv(df):
    # Calculate daily returns
    df['Daily Return'] = df['Close'].diff()
    
    # Calculate the direction of the volume flow
    df['Direction'] = 0
    df.loc[df['Daily Return'] > 0, 'Direction'] = 1
    df.loc[df['Daily Return'] < 0, 'Direction'] = -1
    
    # Calculate OBV
    df['OBV'] = (df['Volume'] * df['Direction']).cumsum()
    
    
    return df['OBV']
    
def calculate_close_open_avg_volume(df):
    # Calculate the average of 'Close' and 'Open' prices
    df['Close_Open_Avg'] = (df['Close'] + df['Open']) / 2
    
    # Multiply the average with 'Volume'
    df['Close_Open_Avg_Volume'] = df['Close_Open_Avg'] * df['Volume']
    
    return df['Close_Open_Avg_Volume']
    
def add_technical_indicators():
    weekly_data_dir = 'weekly_data'
    ta_data_dir = 'ta_data'
    
    if not os.path.exists(ta_data_dir):
        os.makedirs(ta_data_dir)
    
    # List all CSV files in the weekly_data directory
    ticker_files = [f for f in os.listdir(weekly_data_dir) if f.endswith('.csv')]
    
    for file in ticker_files:
        # Load the CSV file into a DataFrame
        df = pd.read_csv(os.path.join(weekly_data_dir, file))
        
        if df.empty:
            continue
        
        # Ensure the date column is in datetime format
        df['date'] = pd.to_datetime(df['date'])
        
        # Sort the dataframe by date
        df.sort_values(by='date', inplace=True)
        
        # Calculate technical indicators
        df['RSI'] = calculate_rsi(df)
        df['MFI'] = calculate_mfi(df)
        df['ULTOSC'] = calculate_ultimate_oscillator(df)
        df['OBV'] = calculate_obv(df)
        df['MON'] = calculate_close_open_avg_volume(df)
        
        # Remove any rows with NaN values introduced by the indicators
        df.dropna(inplace=True)
        
        # Save the updated DataFrame to the ta_data directory
        df.to_csv(os.path.join(ta_data_dir, file), index=False)

# Call the function to execute the task
add_technical_indicators()

# %%
import os
import pandas as pd

def load_ta_data():
    ta_data_dir = 'ta_data'
    
    # List all CSV files in the ta_data directory
    ticker_files = [f for f in os.listdir(ta_data_dir) if f.endswith('.csv')]
    
    # List to store DataFrames
    dataframes = []
    
    for file in ticker_files:
        # Extract the ticker symbol from the file name (assuming it's the file name without extension)
        ticker_symbol = os.path.splitext(file)[0].split('_')[0]
        # Load the CSV file into a DataFrame
        df = pd.read_csv(os.path.join(ta_data_dir, file))
        
        if df.empty:
            continue
        
        # Add a column for the ticker symbol
        df['ticker'] = ticker_symbol
        
        # Remove rows where 'MON' column is less than 1 million
        df = df[df['MON'] >= 1_000_000]   
        
        # Append the DataFrame to the list
        dataframes.append(df)
    
    # Concatenate all DataFrames
    combined_df = pd.concat(dataframes)
    
    # Ensure the date column is in datetime format
    combined_df['date'] = pd.to_datetime(combined_df['date'])
    
    # Set the date column as the index
    combined_df.set_index('date', inplace=True)
    
    return combined_df


# Load the data
combined_df = load_ta_data()
print(combined_df)
# Out:
#                  Open     High        Low      Close  Adj Close     Volume  \
# date
# 2014-12-21   3.286000   3.4720   2.984000   3.200000   0.038866    18420.0
# 2014-12-28   3.550000   3.6475   3.440000   3.600000   0.043724    15125.0
# 2015-01-04   4.147500   4.4200   4.000000   4.295000   0.052165    33350.0
# 2015-01-11   4.398000   4.5540   4.180000   4.360000   0.052955    19340.0
# 2015-01-18   4.568000   4.6920   4.454000   4.640000   0.056355    30880.0
# ...               ...      ...        ...        ...        ...        ...
# 2024-05-12  42.128001  42.9470  41.620799  42.382001  42.382001  4026700.0
# 2024-05-19  44.384000  45.0490  43.564000  44.304000  44.304000  3761720.0
# 2024-05-26  42.140000  42.3770  41.230000  41.314000  41.314000  2514900.0
# 2024-06-02  39.572499  40.3325  39.316250  39.797500  39.797500  3223475.0
# 2024-06-09  41.806000  42.6716  41.508000  42.346000  42.346000  3205060.0
#
#                   RSI        MFI     ULTOSC  Daily Return  Direction  \
# date
# 2014-12-21   2.097897   6.059152  35.369020     -0.198000         -1
# 2014-12-28  24.884254  17.984702  45.268761      0.400000          1
# 2015-01-04  45.758462  38.941819  56.989853      0.695000          1
# 2015-01-11  48.293090  48.508450  55.653852      0.065000          1
# 2015-01-18  55.813953  59.642893  59.043891      0.280000          1
# ...               ...        ...        ...           ...        ...
# 2024-05-12  17.588100  28.634224  31.763922      0.654001          1
# 2024-05-19  25.162183  34.275006  37.247462      1.921999          1
# 2024-05-26  22.643439  37.581561  33.742583     -2.990000         -1
# 2024-06-02  23.517031  38.348862  32.972495     -1.516500         -1
# 2024-06-09  25.420824  37.122140  43.075803      2.548500          1
#
#                    OBV  Close_Open_Avg  Close_Open_Avg_Volume           MON  \
# date
# 2014-12-21    -44595.0        3.243000           5.973606e+04  5.973606e+04
# 2014-12-28    -29470.0        3.575000           5.407187e+04  5.407187e+04
# 2015-01-04      3880.0        4.221250           1.407787e+05  1.407787e+05
# 2015-01-11     23220.0        4.379000           8.468986e+04  8.468986e+04
# 2015-01-18     54100.0        4.604000           1.421715e+05  1.421715e+05
# ...                ...             ...                    ...           ...
# 2024-05-12  81860420.0       42.255001           1.701482e+08  1.701482e+08
# 2024-05-19  85622140.0       44.344000           1.668097e+08  1.668097e+08
# 2024-05-26  83107240.0       41.727000           1.049392e+08  1.049392e+08
# 2024-06-02  79883765.0       39.684999           1.279236e+08  1.279236e+08
# 2024-06-09  83088825.0       42.076000           1.348561e+08  1.348561e+08
#
#            ticker
# date
# 2014-12-21   AACG
# 2014-12-28   AACG
# 2015-01-04   AACG
# 2015-01-11   AACG
# 2015-01-18   AACG
# ...           ...
# 2024-05-12      Z
# 2024-05-19      Z
# 2024-05-26      Z
# 2024-06-02      Z
# 2024-06-09      Z
#
# [1520791 rows x 16 columns]

# %%
import pandas as pd

# Assuming combined_df is already defined and contains the necessary data
# combined_df = ...

# Step 0: Reset index to make 'date' a column
combined_df = combined_df.reset_index()

# Step 1: Sort the DataFrame based on the 'RSI' column for each date in descending order
combined_df = combined_df.sort_values(by=['date', 'RSI'], ascending=[True, False])

# Step 2: Select the top n tickers with the highest RSI score for each date
n = 5  # For example, we can set n to 5
top_n_df = combined_df.groupby('date').head(n).copy()

# Step 3: Calculate the percentage change in the 'Close' column for the selected tickers between the current week and the next week
# Create a new column for the percentage change
top_n_df.loc[:, 'pct_change'] = top_n_df.groupby('ticker')['Close'].pct_change(periods=1) * 100

# Step 4: Summarize the results
summary = top_n_df.dropna(subset=['pct_change'])[['date', 'ticker', 'pct_change']]
print(summary)

# Additionally, you can group by date to see the average percentage change for each date
date_summary = summary.groupby('date')['pct_change'].mean().reset_index()
print(date_summary)

# Step 5: Save the summary to a CSV file
date_summary.to_csv('summary.csv', index=False)
# Out:
#               date ticker  pct_change
# 175356  2014-12-28   BRBS    0.000000
# 1462367 2014-12-28   WMPN    0.000000
# 889484  2014-12-28   PLUS    0.285588
# 772702  2014-12-28   OFLX    7.993307
# 175357  2015-01-04   BRBS    0.000000
# ...            ...    ...         ...
# 272360  2024-06-09  EMLDU    0.682322
# 538704  2024-06-09   HCVI    0.513303
# 986221  2024-06-09   RENE    0.162258
# 1238407 2024-06-09   TENK    4.084246
# 1240135 2024-06-09  TETEU    0.000000
#
# [1746 rows x 3 columns]
#           date  pct_change
# 0   2014-12-28    2.069724
# 1   2015-01-04    0.800600
# 2   2015-01-11   -0.493602
# 3   2015-01-18    2.178041
# 4   2015-01-25    3.137398
# ..         ...         ...
# 485 2024-05-12    1.600000
# 486 2024-05-19   11.720900
# 487 2024-05-26   15.295993
# 488 2024-06-02    3.413522
# 489 2024-06-09    1.088426
#
# [490 rows x 2 columns]
